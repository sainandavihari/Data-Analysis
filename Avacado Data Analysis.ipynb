# %% [markdown]
# ## AVACADO PRICE PREDICTION

# %% [markdown]
# 1.Business Undestanding
#
# Columns:
# 1.Date:the date of observation
# 2.Average Price: Average price of single avacado
# 3.Total volume:Total volume of avacados sold
# 4.4046:total number of 4046 bags sold
# 5.4225:total number of 4225 bags sold
# 6.4770:total number of 4770 bags sold
# 7.total bags:total number of bags
# 8.Small bags:total number of small bags
# 9.Large bags:total number of large bags
# 10.XLarge bags:total number of Large bags
# 11.type:organic or convensional
# 12.year:year
# 13.region:City/Region of this observation

# %%
from IPython.display import Image
url='https://img.etimg.com/thumb/msid-71806721,width-650,imgsize-807917,,resizemode-4,quality-100/avocados.jpg'
Image(url)

# %% [markdown]
# importing all libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
avacado=pd.read_csv(r'C:\Users\STSC\Desktop\ds\OCT\2nd\2nd- reg resume project\RESUME PROJECT -- PRICE PREDICTION\avocado.csv',parse_dates=True, index_col='Date')
avacado.head()
# Out:
#             number   AveragePrice  Total Volume     4046       4225    4770  \
# Date
# 2015-12-27        0          1.33      64236.62  1036.74   54454.85   48.16
# 2015-12-20        1          1.35      54876.98   674.28   44638.81   58.33
# 2015-12-13        2          0.93     118220.22   794.70  109149.67  130.50
# 2015-12-06        3          1.08      78992.15  1132.00   71976.41   72.58
# 2015-11-29        4          1.28      51039.60   941.48   43838.39   75.78
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-12-27     8696.87     8603.62       93.25          0.0  conventional
# 2015-12-20     9505.56     9408.07       97.49          0.0  conventional
# 2015-12-13     8145.35     8042.21      103.14          0.0  conventional
# 2015-12-06     5811.16     5677.40      133.76          0.0  conventional
# 2015-11-29     6183.95     5986.26      197.69          0.0  conventional
#
#             year  region
# Date
# ...

# %%
#removing index from dataframe
avacado.drop(columns=['number '],axis=1,inplace=True)
#avacado.columns

# %%
avacado.head()
# Out:
#             AveragePrice  Total Volume     4046       4225    4770  \
# Date
# 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-12-27     8696.87     8603.62       93.25          0.0  conventional
# 2015-12-20     9505.56     9408.07       97.49          0.0  conventional
# 2015-12-13     8145.35     8042.21      103.14          0.0  conventional
# 2015-12-06     5811.16     5677.40      133.76          0.0  conventional
# 2015-11-29     6183.95     5986.26      197.69          0.0  conventional
#
#             year  region
# Date
# 2015-12-27  2015  Albany
# 2015-12-20  2015  Albany
# ...

# %%
avacado.to_csv('test_write.csv')

# %%
avacado .tail(10)
# Out:
#             AveragePrice  Total Volume     4046     4225    4770  Total Bags  \
# Date
# 2018-03-11          1.56      22128.42  2162.67  3194.25    8.93    16762.57
# 2018-03-04          1.54      17393.30  1832.24  1905.57    0.00    13655.49
# 2018-02-25          1.57      18421.24  1974.26  2482.65    0.00    13964.33
# 2018-02-18          1.56      17597.12  1892.05  1928.36    0.00    13776.71
# 2018-02-11          1.57      15986.17  1924.28  1368.32    0.00    12693.57
# 2018-02-04          1.63      17074.83  2046.96  1529.20    0.00    13498.67
# 2018-01-28          1.71      13888.04  1191.70  3431.50    0.00     9264.84
# 2018-01-21          1.87      13766.76  1191.92  2452.79  727.94     9394.11
# 2018-01-14          1.93      16205.22  1527.63  2981.04  727.01    10969.54
# 2018-01-07          1.62      17489.58  2894.77  2356.13  224.53    12014.15
#
#             Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# ...

# %%
avacado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 18249 entries, 2015-12-27 to 2018-01-07
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 1.8+ MB

# %%
avacado.shape
# Out:
# (18249, 12)

# %%
avacado.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
avacado.values
#this values represents array format of data frame
# Out:
# array([[1.33, 64236.62, 1036.74, ..., 'conventional', 2015, 'Albany'],
#        [1.35, 54876.98, 674.28, ..., 'conventional', 2015, 'Albany'],
#        [0.93, 118220.22, 794.7, ..., 'conventional', 2015, 'Albany'],
#        ...,
#        [1.87, 13766.76, 1191.92, ..., 'organic', 2018,
#         'WestTexNewMexico'],
#        [1.93, 16205.22, 1527.63, ..., 'organic', 2018,
#         'WestTexNewMexico'],
#        [1.62, 17489.58, 2894.77, ..., 'organic', 2018,
#         'WestTexNewMexico']], dtype=object)

# %%
avacado.columns
avacado.reset_index(inplace=True)

# %%
avacado.sort_values(['AveragePrice','year'],ascending =[True,False])
# Out:
#             Date  AveragePrice  Total Volume        4046       4225      4770  \
# 15261 2017-03-05          0.44      64057.04      223.84    4748.88      0.00
# 7412  2017-02-05          0.46    2200550.27  1200632.86  531226.65  18324.93
# 15473 2017-03-05          0.48      50890.73      717.57    4138.84      0.00
# 15262 2017-02-26          0.49      44024.03      252.79    4472.68      0.00
# 1716  2015-12-27          0.49    1137707.43   738314.80  286858.37  11642.46
# ...          ...           ...           ...         ...        ...       ...
# 16720 2017-08-27          3.04      12656.32      419.06    4851.90    145.09
# 16055 2017-03-12          3.05       2068.26     1043.83      77.36      0.00
# 14124 2016-11-06          3.12      19043.80     5898.49   10039.34      0.00
# 17428 2017-04-16          3.17       3018.56     1255.55      82.31      0.00
# 14125 2016-10-30          3.25      16700.94     2325.93   11142.85      0.00
#
# ...

# %%
avacado['AveragePrice']
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
avacado[["AveragePrice","year"]]
# Out:
#        AveragePrice  year
# 0              1.33  2015
# 1              1.35  2015
# 2              0.93  2015
# 3              1.08  2015
# 4              1.28  2015
# ...             ...   ...
# 18244          1.63  2018
# 18245          1.71  2018
# 18246          1.87  2018
# 18247          1.93  2018
# 18248          1.62  2018
#
# [18249 rows x 2 columns]

# %%
#printing row with less than 1 price
avacado[avacado['AveragePrice']<1]
# Out:
#             Date  AveragePrice  Total Volume      4046       4225    4770  \
# 2     2015-12-13          0.93     118220.22    794.70  109149.67  130.50
# 6     2015-11-15          0.99      83453.76   1368.92   73672.72   93.26
# 7     2015-11-08          0.98     109428.33    703.75  101815.36   80.00
# 13    2015-09-27          0.99     106803.39   1204.88   99409.21  154.84
# 43    2015-03-01          0.99      55595.74    629.46   45633.34  181.49
# ...          ...           ...           ...       ...        ...     ...
# 17169 2017-03-05          0.99     155011.12  35367.23    5175.81    5.91
# 17170 2017-02-26          0.99     171145.00  34520.03    6936.39    0.00
# 17536 2017-04-02          0.98     402676.23  34093.33   58330.53  207.85
# 17537 2017-03-26          0.90     456645.91  36169.35   51398.72  139.55
# 17540 2017-03-05          0.99     367519.17  61166.48   55123.99  126.80
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
#printing avacado rows with type organic
avacado[avacado['type']=='organic']
# Out:
#             Date  AveragePrice  Total Volume     4046     4225    4770  \
# 9126  2015-12-27          1.83        989.55     8.16    88.59    0.00
# 9127  2015-12-20          1.89       1163.03    30.24   172.14    0.00
# 9128  2015-12-13          1.85        995.96    10.44   178.70    0.00
# 9129  2015-12-06          1.84       1158.42    90.29   104.18    0.00
# 9130  2015-11-29          1.94        831.69     0.00    94.73    0.00
# ...          ...           ...           ...      ...      ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96  1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70  3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92  2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63  2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# ...

# %%
avacado[avacado['Date']<='2015-02-04']
# Out:
#             Date  AveragePrice  Total Volume     4046      4225    4770  \
# 47    2015-02-01          0.99      70873.60  1353.90  60017.20  179.32
# 48    2015-01-25          1.06      45147.50   941.38  33196.16  164.14
# 49    2015-01-18          1.17      44511.28   914.14  31540.32  135.77
# 50    2015-01-11          1.24      41195.08  1002.85  31640.34  127.12
# 51    2015-01-04          1.22      40873.28  2819.50  28287.42   49.90
# ...          ...           ...           ...      ...       ...     ...
# 11928 2015-02-01          1.77       7210.19  1634.42   3012.44    0.00
# 11929 2015-01-25          1.63       7324.06  1934.46   3032.72    0.00
# 11930 2015-01-18          1.71       5508.20  1793.64   2078.72    0.00
# 11931 2015-01-11          1.69       6861.73  1822.28   2377.54    0.00
# 11932 2015-01-04          1.64       6182.81  1561.30   2958.17    0.00
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
#we need organic avacados which are sold before 5rd february 2015
avacado[(avacado['Date']<='2015-02-05')  & (avacado['type']=='organic')]
# Out:
#             Date  AveragePrice  Total Volume     4046     4225  4770  \
# 9173  2015-02-01          1.83       1228.51    33.12    99.36   0.0
# 9174  2015-01-25          1.89       1115.89    14.87   148.72   0.0
# 9175  2015-01-18          1.93       1118.47     8.02   178.78   0.0
# 9176  2015-01-11          1.77       1182.56    39.00   305.12   0.0
# 9177  2015-01-04          1.79       1373.95    57.42   153.88   0.0
# ...          ...           ...           ...      ...      ...   ...
# 11928 2015-02-01          1.77       7210.19  1634.42  3012.44   0.0
# 11929 2015-01-25          1.63       7324.06  1934.46  3032.72   0.0
# 11930 2015-01-18          1.71       5508.20  1793.64  2078.72   0.0
# 11931 2015-01-11          1.69       6861.73  1822.28  2377.54   0.0
# 11932 2015-01-04          1.64       6182.81  1561.30  2958.17   0.0
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# ...

# %%
#subet avacado in the region Boston,SanDiego

regionFilter=avacado['region'].isin(['Boston','SanDiego'])
avacado[regionFilter]
# Out:
#             Date  AveragePrice  Total Volume     4046       4225      4770  \
# 208   2015-12-27          1.13     450816.39  3886.27  346964.70  13952.56
# 209   2015-12-20          1.07     489802.88  4912.37  390100.99   5887.72
# 210   2015-12-13          1.01     549945.76  4641.02  455362.38    219.40
# 211   2015-12-06          1.02     488679.31  5126.32  407520.22    142.99
# 212   2015-11-29          1.19     350559.81  3609.25  272719.08    105.86
# ...          ...           ...           ...      ...        ...       ...
# 18100 2018-02-04          1.81      17454.74  1158.41    7388.27      0.00
# 18101 2018-01-28          1.91      17579.47  1145.64    8284.41      0.00
# 18102 2018-01-21          1.95      18676.37  1088.49    9282.37      0.00
# 18103 2018-01-14          1.81      21770.02  3285.98   14338.52      0.00
# 18104 2018-01-07          2.06      16746.82  5150.82    9366.31      0.00
#
# ...

# %%
# subset the avocado in the region Boston or SanDiego in the year 2016 or 2017

yearFilter= avacado['year'].isin([2016,2017])
avacado[yearFilter & regionFilter]
# Out:
#             Date  AveragePrice  Total Volume     4046       4225     4770  \
# 3016  2016-12-25          1.28     447600.75  4349.63  346516.32  4183.69
# 3017  2016-12-18          1.09     579577.33  6123.84  488107.01  7765.43
# 3018  2016-12-11          1.22     510800.58  3711.20  409645.98  5052.84
# 3019  2016-12-04          1.26     473428.36  4371.95  393748.18  3449.16
# 3020  2016-11-27          1.45     391257.01  4243.20  317090.39  3069.37
# ...          ...           ...           ...      ...        ...      ...
# 16962 2017-01-29          1.21      18191.46  1477.75    8949.53     4.86
# 16963 2017-01-22          1.73      10842.77  2019.23    6869.87     0.00
# 16964 2017-01-15          1.82      11578.42  2529.20    7637.66     0.00
# 16965 2017-01-08          1.52      16775.97  2363.28    9429.06     0.00
# 16966 2017-01-01          1.45      15752.25  1385.18    8618.28     0.00
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %% [markdown]
# Detecting missing values

# %%
#checking any NAN value present or not
avacado.isna().any()
# Out:
# Date            False
# AveragePrice    False
# Total Volume    False
# 4046            False
# 4225            False
# 4770            False
# Total Bags      False
# Small Bags      False
# Large Bags      False
# XLarge Bags     False
# type            False
# year            False
# region          False
# dtype: bool

# %%
#counting missing values
avacado.isnull().sum().sum()
#So no null values present in dataset
# Out:
# 0

# %% [markdown]
# Removing missing values

# %%
avacado.dropna()

#or

meanval=avacado['AveragePrice'].mean()
avacado.fillna(meanval)
# Out:
#             Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0     2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1     2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2     2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3     2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4     2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...          ...           ...           ...      ...        ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %% [markdown]
# Adding new column to dataframe AveragePrice100

# %%
avacado['AveragePricePer100']=avacado['AveragePrice']*100
avacado.head(4)
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
#
#    region  AveragePricePer100
# 0  Albany               133.0
# 1  Albany               135.0
# 2  Albany                93.0
# 3  Albany               108.0

# %% [markdown]
# deleting columns

# %%
avacado.drop(axis=1,columns=['AveragePricePer100'],inplace=True)
avacado.tail(4)
# Out:
#             Date  AveragePrice  Total Volume     4046     4225    4770  \
# 18245 2018-01-28          1.71      13888.04  1191.70  3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92  2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63  2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18245     9264.84     8940.04      324.80          0.0  organic  2018
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %% [markdown]
# Summary Statistics

# %%
#average avacado price
avacado['AveragePrice'].mean()
# Out:
# 1.405978409775878

# %%
#maximum dates and minimum dates
print(avacado['Date'].max())
print(avacado['Date'].min())
# Out:
# 2018-03-25 00:00:00
# 2015-01-04 00:00:00

# %%
def pct30(col):
    return col.quantile(0.3)
def pct50(col):
    return col.quantile(0.5)
avacado[['AveragePrice','Total Volume']].agg([pct30,pct50])
# Out:
#        AveragePrice  Total Volume
# pct30          1.15     15181.304
# pct50          1.37    107376.760

# %%
#avacado['year'].unique()
#deleting all dublicate year from dataset
avacado.drop_duplicates(['year'])
# Out:
#            Date  AveragePrice  Total Volume      4046       4225    4770  \
# 0    2015-12-27          1.33      64236.62   1036.74   54454.85   48.16
# 2808 2016-12-25          1.52      73341.73   3202.39   58280.33  426.92
# 5616 2017-12-31          1.47     113514.42   2622.70  101135.53   20.25
# 8478 2018-03-25          1.57     149396.50  16361.69  109045.03   65.45
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0        8696.87     8603.62       93.25         0.00  conventional  2015
# 2808    11432.09    11017.32      411.83         2.94  conventional  2016
# 5616     9735.94     5556.98     4178.96         0.00  conventional  2017
# 8478    23924.33    19273.80     4270.53       380.00  conventional  2018
#
#       region
# 0     Albany
# 2808  Albany
# 5616  Albany
# 8478  Albany

# %%
#count number of avocado in each year in descending order
avacado['year'].value_counts(ascending=False)
# Out:
# year
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: count, dtype: int64

# %%
#group by multiple columns and perform multiple statistical operations
avacado.groupby(['year','type'])['AveragePrice'].agg([max,min,np.mean,np.median])
# Out:
#                     max   min      mean  median
# year type
# 2015 conventional  1.59  0.49  1.077963    1.08
#      organic       2.79  0.81  1.673324    1.67
# 2016 conventional  2.20  0.51  1.105595    1.08
#      organic       3.25  0.58  1.571684    1.53
# 2017 conventional  2.22  0.46  1.294888    1.30
#      organic       3.17  0.44  1.735521    1.72
# 2018 conventional  1.74  0.56  1.127886    1.14
#      organic       2.30  1.01  1.567176    1.55

# %%
avacado.pivot_table(index=['year','type'],aggfunc=[max,min,np.mean,np.median],values='AveragePrice')
# Out:
#                            max          min         mean       median
#                   AveragePrice AveragePrice AveragePrice AveragePrice
# year type
# 2015 conventional         1.59         0.49     1.077963         1.08
#      organic              2.79         0.81     1.673324         1.67
# 2016 conventional         2.20         0.51     1.105595         1.08
#      organic              3.25         0.58     1.571684         1.53
# 2017 conventional         2.22         0.46     1.294888         1.30
#      organic              3.17         0.44     1.735521         1.72
# 2018 conventional         1.74         0.56     1.127886         1.14
#      organic              2.30         1.01     1.567176         1.55

# %%
#making region as index
regionIndex=avacado.set_index(['region'])
regionIndex
# Out:
#                        Date  AveragePrice  Total Volume     4046       4225  \
# region
# Albany           2015-12-27          1.33      64236.62  1036.74   54454.85
# Albany           2015-12-20          1.35      54876.98   674.28   44638.81
# Albany           2015-12-13          0.93     118220.22   794.70  109149.67
# Albany           2015-12-06          1.08      78992.15  1132.00   71976.41
# Albany           2015-11-29          1.28      51039.60   941.48   43838.39
# ...                     ...           ...           ...      ...        ...
# WestTexNewMexico 2018-02-04          1.63      17074.83  2046.96    1529.20
# WestTexNewMexico 2018-01-28          1.71      13888.04  1191.70    3431.50
# WestTexNewMexico 2018-01-21          1.87      13766.76  1191.92    2452.79
# WestTexNewMexico 2018-01-14          1.93      16205.22  1527.63    2981.04
# WestTexNewMexico 2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
#collecting ablany and WestTexNewMexico region records
avacado[avacado['region'].isin(['Albany','WestTexNewMexico'])]
# Out:
#             Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0     2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1     2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2     2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3     2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4     2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...          ...           ...           ...      ...        ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %% [markdown]
# ### Visualization

# %%
#visualization using histogram
avacado['AveragePrice'].hist(bins=20)
# Out:
# <Axes: >

# %%
#average price of avacado for each region 
regionFilter=avacado.groupby('region')['AveragePrice'].mean()
regionFilter.head()
# Out:
# region
# Albany                 1.561036
# Atlanta                1.337959
# BaltimoreWashington    1.534231
# Boise                  1.348136
# Boston                 1.530888
# Name: AveragePrice, dtype: float64

# %%
regionFilter.plot(kind='bar',fontsize=8,figsize=(10,3),title="Average price in all regions")
# Out:
# <Axes: title={'center': 'Average price in all regions'}, xlabel='region'>

# %%
#from above plots,HartsfordSpringfield,SanFrancisco has heighest average avacado prices

# %%
avacado.plot(kind='scatter',y='Total Volume',x='AveragePrice')
# Out:
# <Axes: xlabel='AveragePrice', ylabel='Total Volume'>

# %%
#Subtract average price with its mean and plotting k-distribution plot
d=round(avacado['AveragePrice'].sub(avacado['AveragePrice'].mean()),2)
d.plot(kind='kde',title='average price')
# Out:
# <Axes: title={'center': 'average price'}, ylabel='Density'>

# %%
avacado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  datetime64[ns]
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(1), object(2)
# memory usage: 1.8+ MB

# %%
sns.displot(avacado['AveragePrice'],kind='hist')

# %%
sns.countplot(x='year',data=avacado,hue='type')
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %% [markdown]
# convensional and organic avacados are same in every year and there are less avacados in 2018 when we comparing from 2015

# %%
avacado.year.value_counts()
# Out:
# year
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: count, dtype: int64

# %%
sns.boxenplot(y='AveragePrice',x='year',data=avacado)
# Out:
# <Axes: xlabel='year', ylabel='AveragePrice'>

# %%
sns.boxplot(y='AveragePrice',x='type',data=avacado)
# Out:
# <Axes: xlabel='type', ylabel='AveragePrice'>

# %% [markdown]
# Organic avacados are high expensive when we compare with conventional avacado price

# %% [markdown]
# #### dealing with categorical variable

# %%
avacado['type']=avacado['type'].map({'conventional':0,'organic':1})

avacado['Date']=avacado.Date.apply(pd.to_datetime)
avacado['Date']
# Out:
# 0       2015-12-27
# 1       2015-12-20
# 2       2015-12-13
# 3       2015-12-06
# 4       2015-11-29
#            ...
# 18244   2018-02-04
# 18245   2018-01-28
# 18246   2018-01-21
# 18247   2018-01-14
# 18248   2018-01-07
# Name: Date, Length: 18249, dtype: datetime64[ns]
